# %%
import os
import math
import random as rand
from tqdm import tqdm, trange

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from transformers import AutoTokenizer, AutoModel, TFBertForSequenceClassification
from datasets import Dataset
import evaluate

import tensorflow as tf

from sklearn.metrics import confusion_matrix, f1_score, recall_score, precision_score

# %%
# Data Loading

# %%
def func_betolt(lr, Trainable, train_dataset, val_dataset, test_dataset, tokenizer):
        # Load BERT tokenizer
        # tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

        # Load BERT model
        model = TFBertForSequenceClassification.from_pretrained("dmis-lab/biobert-v1.1", from_pt=True)

        # Set up optimizer and loss function
        optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
        loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        
        # transfer learning vs re-training pre-trained BERT model on smaller lr
        model.layers[0].trainable = Trainable
        print ("Learning rate: " + str(lr) + "    Trainable: " + str(Trainable))
        model.summary()
        model.compile(optimizer=optimizer, loss=loss, metrics=['sparse_categorical_accuracy'])
        es = tf.keras.callbacks.EarlyStopping(patience=10, monitor="val_loss", restore_best_weights=True)
        hist = model.fit(train_dataset, epochs=1000, 
                validation_data=val_dataset,
                callbacks=[es],
                verbose=1)
        
        #plt.plot(hist.history["loss"])
        #plt.plot(hist.history["val_loss"])
        vissza = [len(hist.history["loss"]), model.evaluate(train_dataset, verbose=0), model.evaluate(val_dataset, verbose=0), model.evaluate(test_dataset, verbose=0)]
        return vissza

# %%
dataset = 'title_abstract_keywords'

# %%
df = pd.read_pickle("data/train_{}.pkl".format(dataset))

# %%
df.head()
# Out:
#    label                                               text
# 0      1  Comparing measurement properties of EQ-5D-Y-3L...
# 1      0  Feasibility of the EQ-5D in the elderly popula...
# 2      1  Comparing the self-reported health-related qua...
# 3      1  Testing measurement properties of two EQ-5D yo...
# 4      1  Use of Antimalarial Agents is Associated with ...

# %%
train_dataset = Dataset.from_pandas(df)

# %%
train_dataset[0]
# Out:
# {'label': 1,
#  'text': 'Comparing measurement properties of EQ-5D-Y-3L and EQ-5D-Y-5L in paediatric patients [SEP] BACKGROUND: The adult versions EQ-5D-3L and EQ-5D-5L have been extensive compared. This is not the case for the EQ-5D youth versions. The study aim was to compare the measurement properties and responsiveness of EQ-5D-Y-3L and EQ-5D-Y-5L in paediatric patients. METHODS: A sample of patients 8-16\xa0years old with different diseases and a wide range of disease severity was asked to complete EQ-5D-Y-3L, EQ-5D-Y-5L, PedsQL Generic Core Scale, and selected, appropriate disease-specific instruments, three times. EQ-5D-Y-3L and EQ-5D-Y-5L were compared in terms of: feasibility, (re-)distribution properties, discriminatory power, convergent validity, test-retest reliability, and responsiveness. RESULTS: 286 participating patients suffered from one of the following diseases: major beta-thalassemia, haemophilia, acute lymphoblastic leukaemia, acute illness. Missing responses were comparable between versions of the EQ-5D-Y, suggesting comparable feasibility. The number of patients in the best health state (level profile 11111) was equal in both EQ-5D-Y versions. The projection of EQ-5D-Y-3L scores onto EQ-5D-Y-5L for all dimensions showed that the two additional levels in EQ-5D-Y-5L slightly improved the accuracy of patients in reporting their problems, especially if severe. Convergent validity with PedsQL and disease-specific measures showed that the two EQ-5D-Y versions performed about equally. Test-retest reliability (EQ-5D-Y-3L 0.78 vs EQ-5D-Y-5L 0.84), and sensitivity for detecting health changes, were both better in EQ-5D-Y-5L. CONCLUSIONS: Extending the number of levels did not give clear superiority to EQ-5D-Y-5L over EQ-5D-Y-3L based on the criteria assessed in this study. However, increasing the number of levels benefitted EQ-5D-Y performance in the measurement of moderate to severe problems and especially in longitudinal study designs [SEP] Adolescent; Adult; Child; Humans; Longitudinal Studies; Psychometrics; Quality of Life; Reproducibility of Results; Surveys and Questionnaires; EQ-5D-Y-3L paediatric patients; EQ-5D-Y-5L; Health-related quality of life; Psychometrics'}

# %%
#random stratified validation subset split
#_diff = 1
#while _diff >= .02:
#    tts = train_dataset.train_test_split(test_size=.15, shuffle=True)
#    _train_ratio, _val_ratio = np.sum(tts["train"]["label"]) / len(tts["train"]["label"]), np.sum(tts["test"]["label"]) / len(tts["test"]["label"])
#    _diff = abs(_train_ratio - _val_ratio)
#    print(_train_ratio, _val_ratio, _diff)
#
#train_dataset = tts["train"]
#val_dataset = tts["test"]


#subsets should be fixed for all tests
_val_ids = [2, 7, 24, 32, 36, 47, 49, 59, 61, 71, 72, 86, 90, 95, 96]
train_dataset = Dataset.from_pandas(df[~df.index.isin(_val_ids)])
val_dataset = Dataset.from_pandas(df[df.index.isin(_val_ids)])

# %%
np.sum(train_dataset["label"]) / len(train_dataset["label"]), np.sum(val_dataset["label"]) / len(val_dataset["label"])
# Out:
# (0.611764705882353, 0.6)

# %%
train_dataset[0]
# Out:
# {'label': 1,
#  'text': 'Comparing measurement properties of EQ-5D-Y-3L and EQ-5D-Y-5L in paediatric patients [SEP] BACKGROUND: The adult versions EQ-5D-3L and EQ-5D-5L have been extensive compared. This is not the case for the EQ-5D youth versions. The study aim was to compare the measurement properties and responsiveness of EQ-5D-Y-3L and EQ-5D-Y-5L in paediatric patients. METHODS: A sample of patients 8-16\xa0years old with different diseases and a wide range of disease severity was asked to complete EQ-5D-Y-3L, EQ-5D-Y-5L, PedsQL Generic Core Scale, and selected, appropriate disease-specific instruments, three times. EQ-5D-Y-3L and EQ-5D-Y-5L were compared in terms of: feasibility, (re-)distribution properties, discriminatory power, convergent validity, test-retest reliability, and responsiveness. RESULTS: 286 participating patients suffered from one of the following diseases: major beta-thalassemia, haemophilia, acute lymphoblastic leukaemia, acute illness. Missing responses were comparable between versions of the EQ-5D-Y, suggesting comparable feasibility. The number of patients in the best health state (level profile 11111) was equal in both EQ-5D-Y versions. The projection of EQ-5D-Y-3L scores onto EQ-5D-Y-5L for all dimensions showed that the two additional levels in EQ-5D-Y-5L slightly improved the accuracy of patients in reporting their problems, especially if severe. Convergent validity with PedsQL and disease-specific measures showed that the two EQ-5D-Y versions performed about equally. Test-retest reliability (EQ-5D-Y-3L 0.78 vs EQ-5D-Y-5L 0.84), and sensitivity for detecting health changes, were both better in EQ-5D-Y-5L. CONCLUSIONS: Extending the number of levels did not give clear superiority to EQ-5D-Y-5L over EQ-5D-Y-3L based on the criteria assessed in this study. However, increasing the number of levels benefitted EQ-5D-Y performance in the measurement of moderate to severe problems and especially in longitudinal study designs [SEP] Adolescent; Adult; Child; Humans; Longitudinal Studies; Psychometrics; Quality of Life; Reproducibility of Results; Surveys and Questionnaires; EQ-5D-Y-3L paediatric patients; EQ-5D-Y-5L; Health-related quality of life; Psychometrics',
#  '__index_level_0__': 0}

# %%
df = pd.read_pickle("data/test_{}.pkl".format(dataset))

# %%
test_dataset = Dataset.from_pandas(df)

# %%
np.sum(test_dataset["label"]) / len(test_dataset["label"])
# Out:
# 0.6

# %% [markdown]
# # Preparation for training

# %%
tokenizer = AutoTokenizer.from_pretrained("dmis-lab/biobert-v1.1")

# %%
#def preprocess_function(examples):
#    return tokenizer(examples["text"], truncation=True, padding=True)

# %%
#encodings = dataset.map(preprocess_function, batched=True)
train_encodings = tokenizer(train_dataset["text"], truncation=True, padding=True, max_length=512)
val_encodings = tokenizer(val_dataset["text"], truncation=True, padding=True, max_length=512)
test_encodings = tokenizer(test_dataset["text"], truncation=True, padding=True, max_length=512)

# %%
len(train_encodings[0]), len(train_encodings[1]), len(train_encodings[2])
# Out:
# (512, 512, 512)

# %%
np.mean([np.sum([t == '[PAD]' for t in train_encodings[e].tokens]) for e in range(0,80)])
# Out:
# 30.8375

# %%
train_labels = train_dataset["label"]
val_labels = val_dataset["label"]
test_labels = test_dataset["label"]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((
    dict(train_encodings),
    train_labels
)).shuffle(100).batch(16)

val_dataset = tf.data.Dataset.from_tensor_slices((
    dict(val_encodings),
    val_labels
)).shuffle(100).batch(16)

test_dataset = tf.data.Dataset.from_tensor_slices((
    dict(test_encodings),
    test_labels
)).batch(16)

# %%
# Load BERT tokenizer
# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Load BERT model
Trainable = False
# 1e-4, 2e-4, 5e-4, 1e-5, 2e-5, 5e-5, 1e-6, 

for lr in [1e-4, 2e-4, 5e-4, 1e-5, 2e-5, 5e-5, 1e-6, 2e-6, 5e-6]:
    for Ismetles in range (0,5):
        TestEredmeny = func_betolt(lr, Trainable, train_dataset, val_dataset, test_dataset, tokenizer)
        print(lr,  TestEredmeny)
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Learning rate: 2e-06    Trainable: False
# Model: "tf_bert_for_sequence_classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bert (TFBertMainLayer)      multiple                  108310272
#
#  dropout_37 (Dropout)        multiple                  0
#
#  classifier (Dense)          multiple                  1538
#
# =================================================================
# Total params: 108,311,810
# Trainable params: 1,538
# Non-trainable params: 108,310,272
# _________________________________________________________________
# Epoch 1/1000
# 6/6 [==============================] - 51s 6s/step - loss: 0.6947 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6674 - val_sparse_categorical_accuracy: 0.6667
# Epoch 2/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7066 - sparse_categorical_accuracy: 0.5412 - val_loss: 0.6674 - val_sparse_categorical_accuracy: 0.6667
# Epoch 3/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6850 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6674 - val_sparse_categorical_accuracy: 0.6667
# Epoch 4/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6770 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6675 - val_sparse_categorical_accuracy: 0.6667
# Epoch 5/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6930 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6675 - val_sparse_categorical_accuracy: 0.6667
# Epoch 6/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6827 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6675 - val_sparse_categorical_accuracy: 0.6667
# Epoch 7/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6959 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6675 - val_sparse_categorical_accuracy: 0.6667
# Epoch 8/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7029 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.6675 - val_sparse_categorical_accuracy: 0.6667
# Epoch 9/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6858 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6676 - val_sparse_categorical_accuracy: 0.6667
# Epoch 10/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7028 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6676 - val_sparse_categorical_accuracy: 0.6667
# Epoch 11/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6826 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6676 - val_sparse_categorical_accuracy: 0.6667
# 2e-06 [11, [0.6934353709220886, 0.6000000238418579], [0.6673544049263, 0.6666666865348816], [0.6921703219413757, 0.5699999928474426]]
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Learning rate: 2e-06    Trainable: False
# Model: "tf_bert_for_sequence_classification_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bert (TFBertMainLayer)      multiple                  108310272
#
#  dropout_75 (Dropout)        multiple                  0
#
#  classifier (Dense)          multiple                  1538
#
# =================================================================
# Total params: 108,311,810
# Trainable params: 1,538
# Non-trainable params: 108,310,272
# _________________________________________________________________
# Epoch 1/1000
# 6/6 [==============================] - 46s 6s/step - loss: 0.7052 - sparse_categorical_accuracy: 0.4941 - val_loss: 0.7269 - val_sparse_categorical_accuracy: 0.2667
# Epoch 2/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7088 - sparse_categorical_accuracy: 0.4235 - val_loss: 0.7265 - val_sparse_categorical_accuracy: 0.2667
# Epoch 3/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7031 - sparse_categorical_accuracy: 0.4588 - val_loss: 0.7260 - val_sparse_categorical_accuracy: 0.3333
# Epoch 4/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7164 - sparse_categorical_accuracy: 0.3765 - val_loss: 0.7256 - val_sparse_categorical_accuracy: 0.3333
# Epoch 5/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7030 - sparse_categorical_accuracy: 0.4706 - val_loss: 0.7252 - val_sparse_categorical_accuracy: 0.3333
# Epoch 6/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7027 - sparse_categorical_accuracy: 0.4941 - val_loss: 0.7248 - val_sparse_categorical_accuracy: 0.3333
# Epoch 7/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6976 - sparse_categorical_accuracy: 0.5529 - val_loss: 0.7243 - val_sparse_categorical_accuracy: 0.3333
# Epoch 8/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6996 - sparse_categorical_accuracy: 0.4471 - val_loss: 0.7239 - val_sparse_categorical_accuracy: 0.3333
# Epoch 9/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7012 - sparse_categorical_accuracy: 0.4941 - val_loss: 0.7234 - val_sparse_categorical_accuracy: 0.2000
# Epoch 10/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6908 - sparse_categorical_accuracy: 0.5529 - val_loss: 0.7230 - val_sparse_categorical_accuracy: 0.2000
# Epoch 11/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7146 - sparse_categorical_accuracy: 0.4118 - val_loss: 0.7225 - val_sparse_categorical_accuracy: 0.2000
# Epoch 12/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5529 - val_loss: 0.7221 - val_sparse_categorical_accuracy: 0.2000
# Epoch 13/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6941 - sparse_categorical_accuracy: 0.4824 - val_loss: 0.7216 - val_sparse_categorical_accuracy: 0.2000
# Epoch 14/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6964 - sparse_categorical_accuracy: 0.5529 - val_loss: 0.7212 - val_sparse_categorical_accuracy: 0.2000
# Epoch 15/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7030 - sparse_categorical_accuracy: 0.4941 - val_loss: 0.7209 - val_sparse_categorical_accuracy: 0.2000
# Epoch 16/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6922 - sparse_categorical_accuracy: 0.5059 - val_loss: 0.7206 - val_sparse_categorical_accuracy: 0.2000
# Epoch 17/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7001 - sparse_categorical_accuracy: 0.4706 - val_loss: 0.7204 - val_sparse_categorical_accuracy: 0.2000
# Epoch 18/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6917 - sparse_categorical_accuracy: 0.4706 - val_loss: 0.7200 - val_sparse_categorical_accuracy: 0.2000
# Epoch 19/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6946 - sparse_categorical_accuracy: 0.5412 - val_loss: 0.7196 - val_sparse_categorical_accuracy: 0.2000
# Epoch 20/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7084 - sparse_categorical_accuracy: 0.4353 - val_loss: 0.7194 - val_sparse_categorical_accuracy: 0.2000
# Epoch 21/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6931 - sparse_categorical_accuracy: 0.4706 - val_loss: 0.7191 - val_sparse_categorical_accuracy: 0.2000
# Epoch 22/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6909 - sparse_categorical_accuracy: 0.5412 - val_loss: 0.7188 - val_sparse_categorical_accuracy: 0.2667
# Epoch 23/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7000 - sparse_categorical_accuracy: 0.4706 - val_loss: 0.7185 - val_sparse_categorical_accuracy: 0.3333
# Epoch 24/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6939 - sparse_categorical_accuracy: 0.5529 - val_loss: 0.7181 - val_sparse_categorical_accuracy: 0.3333
# Epoch 25/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7058 - sparse_categorical_accuracy: 0.4941 - val_loss: 0.7177 - val_sparse_categorical_accuracy: 0.2667
# Epoch 26/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6943 - sparse_categorical_accuracy: 0.4941 - val_loss: 0.7174 - val_sparse_categorical_accuracy: 0.2667
# Epoch 27/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7171 - val_sparse_categorical_accuracy: 0.2667
# Epoch 28/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6819 - sparse_categorical_accuracy: 0.5529 - val_loss: 0.7170 - val_sparse_categorical_accuracy: 0.2667
# Epoch 29/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6837 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.7167 - val_sparse_categorical_accuracy: 0.2667
# Epoch 30/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6954 - sparse_categorical_accuracy: 0.4941 - val_loss: 0.7164 - val_sparse_categorical_accuracy: 0.3333
# Epoch 31/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6971 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7161 - val_sparse_categorical_accuracy: 0.3333
# Epoch 32/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6954 - sparse_categorical_accuracy: 0.5176 - val_loss: 0.7159 - val_sparse_categorical_accuracy: 0.3333
# Epoch 33/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6933 - sparse_categorical_accuracy: 0.4706 - val_loss: 0.7156 - val_sparse_categorical_accuracy: 0.3333
# Epoch 34/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6886 - sparse_categorical_accuracy: 0.5176 - val_loss: 0.7153 - val_sparse_categorical_accuracy: 0.3333
# Epoch 35/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6969 - sparse_categorical_accuracy: 0.4471 - val_loss: 0.7151 - val_sparse_categorical_accuracy: 0.3333
# Epoch 36/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6985 - sparse_categorical_accuracy: 0.4706 - val_loss: 0.7149 - val_sparse_categorical_accuracy: 0.2667
# Epoch 37/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6824 - sparse_categorical_accuracy: 0.5412 - val_loss: 0.7146 - val_sparse_categorical_accuracy: 0.2667
# Epoch 38/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6729 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7144 - val_sparse_categorical_accuracy: 0.2667
# Epoch 39/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6875 - sparse_categorical_accuracy: 0.5529 - val_loss: 0.7143 - val_sparse_categorical_accuracy: 0.2667
# Epoch 40/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6851 - sparse_categorical_accuracy: 0.4824 - val_loss: 0.7141 - val_sparse_categorical_accuracy: 0.4000
# Epoch 41/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.7027 - sparse_categorical_accuracy: 0.4588 - val_loss: 0.7139 - val_sparse_categorical_accuracy: 0.4000
# Epoch 42/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6951 - sparse_categorical_accuracy: 0.5294 - val_loss: 0.7137 - val_sparse_categorical_accuracy: 0.4000
# Epoch 43/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6974 - sparse_categorical_accuracy: 0.5294 - val_loss: 0.7134 - val_sparse_categorical_accuracy: 0.4667
# Epoch 44/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6841 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7132 - val_sparse_categorical_accuracy: 0.4667
# Epoch 45/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6918 - sparse_categorical_accuracy: 0.5059 - val_loss: 0.7130 - val_sparse_categorical_accuracy: 0.4667
# Epoch 46/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6855 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7128 - val_sparse_categorical_accuracy: 0.4667
# Epoch 47/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6989 - sparse_categorical_accuracy: 0.5294 - val_loss: 0.7127 - val_sparse_categorical_accuracy: 0.4667
# Epoch 48/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6872 - sparse_categorical_accuracy: 0.5294 - val_loss: 0.7124 - val_sparse_categorical_accuracy: 0.5333
# Epoch 49/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6893 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7123 - val_sparse_categorical_accuracy: 0.5333
# Epoch 50/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6966 - sparse_categorical_accuracy: 0.5059 - val_loss: 0.7121 - val_sparse_categorical_accuracy: 0.5333
# Epoch 51/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6873 - sparse_categorical_accuracy: 0.5412 - val_loss: 0.7119 - val_sparse_categorical_accuracy: 0.5333
# Epoch 52/1000
# 6/6 [==============================] - 32s 5s/step - loss: 0.6867 - sparse_categorical_accuracy: 0.5412 - val_loss: 0.7117 - val_sparse_categorical_accuracy: 0.5333
# Epoch 53/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6892 - sparse_categorical_accuracy: 0.5412 - val_loss: 0.7115 - val_sparse_categorical_accuracy: 0.5333
# Epoch 54/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6952 - sparse_categorical_accuracy: 0.5412 - val_loss: 0.7113 - val_sparse_categorical_accuracy: 0.5333
# Epoch 55/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6926 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7110 - val_sparse_categorical_accuracy: 0.5333
# Epoch 56/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6948 - sparse_categorical_accuracy: 0.5176 - val_loss: 0.7109 - val_sparse_categorical_accuracy: 0.5333
# Epoch 57/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6922 - sparse_categorical_accuracy: 0.4941 - val_loss: 0.7107 - val_sparse_categorical_accuracy: 0.5333
# Epoch 58/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6823 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7105 - val_sparse_categorical_accuracy: 0.5333
# Epoch 59/1000
# 6/6 [==============================] - 32s 5s/step - loss: 0.6910 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7103 - val_sparse_categorical_accuracy: 0.6000
# Epoch 60/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6924 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7100 - val_sparse_categorical_accuracy: 0.6000
# Epoch 61/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6906 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7097 - val_sparse_categorical_accuracy: 0.6000
# Epoch 62/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6902 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7095 - val_sparse_categorical_accuracy: 0.6000
# Epoch 63/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6869 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7093 - val_sparse_categorical_accuracy: 0.6000
# Epoch 64/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6905 - sparse_categorical_accuracy: 0.5529 - val_loss: 0.7091 - val_sparse_categorical_accuracy: 0.6000
# Epoch 65/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6805 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7089 - val_sparse_categorical_accuracy: 0.6000
# Epoch 66/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6927 - sparse_categorical_accuracy: 0.4941 - val_loss: 0.7087 - val_sparse_categorical_accuracy: 0.6000
# Epoch 67/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6917 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7086 - val_sparse_categorical_accuracy: 0.6000
# Epoch 68/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6887 - sparse_categorical_accuracy: 0.5294 - val_loss: 0.7085 - val_sparse_categorical_accuracy: 0.6000
# Epoch 69/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6888 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7084 - val_sparse_categorical_accuracy: 0.6000
# Epoch 70/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6776 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7082 - val_sparse_categorical_accuracy: 0.6000
# Epoch 71/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6888 - sparse_categorical_accuracy: 0.5059 - val_loss: 0.7080 - val_sparse_categorical_accuracy: 0.6000
# Epoch 72/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6815 - sparse_categorical_accuracy: 0.5412 - val_loss: 0.7079 - val_sparse_categorical_accuracy: 0.6000
# Epoch 73/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6708 - sparse_categorical_accuracy: 0.6471 - val_loss: 0.7077 - val_sparse_categorical_accuracy: 0.6000
# Epoch 74/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6800 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7076 - val_sparse_categorical_accuracy: 0.6000
# Epoch 75/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6788 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.7075 - val_sparse_categorical_accuracy: 0.6000
# Epoch 76/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6875 - sparse_categorical_accuracy: 0.5529 - val_loss: 0.7074 - val_sparse_categorical_accuracy: 0.6000
# Epoch 77/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6719 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7072 - val_sparse_categorical_accuracy: 0.6000
# Epoch 78/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6883 - sparse_categorical_accuracy: 0.5412 - val_loss: 0.7070 - val_sparse_categorical_accuracy: 0.6000
# Epoch 79/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6954 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7070 - val_sparse_categorical_accuracy: 0.6000
# Epoch 80/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6799 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7068 - val_sparse_categorical_accuracy: 0.6000
# Epoch 81/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6756 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7067 - val_sparse_categorical_accuracy: 0.6000
# Epoch 82/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6811 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.7067 - val_sparse_categorical_accuracy: 0.6000
# Epoch 83/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6841 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7066 - val_sparse_categorical_accuracy: 0.6000
# Epoch 84/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6860 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.7064 - val_sparse_categorical_accuracy: 0.6000
# Epoch 85/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6727 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.7063 - val_sparse_categorical_accuracy: 0.6000
# Epoch 86/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6766 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7062 - val_sparse_categorical_accuracy: 0.6000
# Epoch 87/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6802 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7061 - val_sparse_categorical_accuracy: 0.6000
# Epoch 88/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6773 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7060 - val_sparse_categorical_accuracy: 0.6000
# Epoch 89/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6721 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.7058 - val_sparse_categorical_accuracy: 0.6000
# Epoch 90/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6835 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7056 - val_sparse_categorical_accuracy: 0.6000
# Epoch 91/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6762 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7055 - val_sparse_categorical_accuracy: 0.6000
# Epoch 92/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6840 - sparse_categorical_accuracy: 0.5412 - val_loss: 0.7053 - val_sparse_categorical_accuracy: 0.6000
# Epoch 93/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6860 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.7052 - val_sparse_categorical_accuracy: 0.6000
# Epoch 94/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6891 - sparse_categorical_accuracy: 0.5294 - val_loss: 0.7051 - val_sparse_categorical_accuracy: 0.6000
# Epoch 95/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6793 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7050 - val_sparse_categorical_accuracy: 0.6000
# Epoch 96/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6749 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7049 - val_sparse_categorical_accuracy: 0.6000
# Epoch 97/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6815 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7048 - val_sparse_categorical_accuracy: 0.6000
# Epoch 98/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6869 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.7047 - val_sparse_categorical_accuracy: 0.6000
# Epoch 99/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6810 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7046 - val_sparse_categorical_accuracy: 0.6000
# Epoch 100/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6802 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7045 - val_sparse_categorical_accuracy: 0.6000
# Epoch 101/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6843 - sparse_categorical_accuracy: 0.5529 - val_loss: 0.7044 - val_sparse_categorical_accuracy: 0.6000
# Epoch 102/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6911 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7043 - val_sparse_categorical_accuracy: 0.6000
# Epoch 103/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6891 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7042 - val_sparse_categorical_accuracy: 0.6000
# Epoch 104/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6680 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7041 - val_sparse_categorical_accuracy: 0.6000
# Epoch 105/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6870 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7041 - val_sparse_categorical_accuracy: 0.6000
# Epoch 106/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6653 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7040 - val_sparse_categorical_accuracy: 0.6000
# Epoch 107/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6763 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7039 - val_sparse_categorical_accuracy: 0.6000
# Epoch 108/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6706 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7038 - val_sparse_categorical_accuracy: 0.6000
# Epoch 109/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6803 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7037 - val_sparse_categorical_accuracy: 0.6000
# Epoch 110/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6826 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7035 - val_sparse_categorical_accuracy: 0.6000
# Epoch 111/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6745 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.7035 - val_sparse_categorical_accuracy: 0.6000
# Epoch 112/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6688 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7034 - val_sparse_categorical_accuracy: 0.6000
# Epoch 113/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6731 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7033 - val_sparse_categorical_accuracy: 0.6000
# Epoch 114/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6736 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7033 - val_sparse_categorical_accuracy: 0.6000
# Epoch 115/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6749 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7032 - val_sparse_categorical_accuracy: 0.6000
# Epoch 116/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6793 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.7030 - val_sparse_categorical_accuracy: 0.6000
# Epoch 117/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6774 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7030 - val_sparse_categorical_accuracy: 0.6000
# Epoch 118/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6651 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7029 - val_sparse_categorical_accuracy: 0.6000
# Epoch 119/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6766 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7029 - val_sparse_categorical_accuracy: 0.6000
# Epoch 120/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6803 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7028 - val_sparse_categorical_accuracy: 0.6000
# Epoch 121/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6901 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7027 - val_sparse_categorical_accuracy: 0.6000
# Epoch 122/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6914 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7026 - val_sparse_categorical_accuracy: 0.6000
# Epoch 123/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6799 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7026 - val_sparse_categorical_accuracy: 0.6000
# Epoch 124/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6717 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7025 - val_sparse_categorical_accuracy: 0.6000
# Epoch 125/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6688 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7025 - val_sparse_categorical_accuracy: 0.6000
# Epoch 126/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6741 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7025 - val_sparse_categorical_accuracy: 0.6000
# Epoch 127/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6808 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7024 - val_sparse_categorical_accuracy: 0.6000
# Epoch 128/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6716 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7024 - val_sparse_categorical_accuracy: 0.6000
# Epoch 129/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6690 - sparse_categorical_accuracy: 0.6471 - val_loss: 0.7024 - val_sparse_categorical_accuracy: 0.6000
# Epoch 130/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6938 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7024 - val_sparse_categorical_accuracy: 0.6000
# Epoch 131/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6838 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7023 - val_sparse_categorical_accuracy: 0.6000
# Epoch 132/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6812 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7022 - val_sparse_categorical_accuracy: 0.6000
# Epoch 133/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6718 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7022 - val_sparse_categorical_accuracy: 0.6000
# Epoch 134/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6733 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7021 - val_sparse_categorical_accuracy: 0.6000
# Epoch 135/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6842 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7021 - val_sparse_categorical_accuracy: 0.6000
# Epoch 136/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6864 - sparse_categorical_accuracy: 0.5529 - val_loss: 0.7020 - val_sparse_categorical_accuracy: 0.6000
# Epoch 137/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6783 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7020 - val_sparse_categorical_accuracy: 0.6000
# Epoch 138/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6796 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7019 - val_sparse_categorical_accuracy: 0.6000
# Epoch 139/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6879 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7018 - val_sparse_categorical_accuracy: 0.6000
# Epoch 140/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6794 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7017 - val_sparse_categorical_accuracy: 0.6000
# Epoch 141/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6706 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7017 - val_sparse_categorical_accuracy: 0.6000
# Epoch 142/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6774 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7016 - val_sparse_categorical_accuracy: 0.6000
# Epoch 143/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6789 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7016 - val_sparse_categorical_accuracy: 0.6000
# Epoch 144/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6797 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7015 - val_sparse_categorical_accuracy: 0.6000
# Epoch 145/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6674 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7015 - val_sparse_categorical_accuracy: 0.6000
# Epoch 146/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6633 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.7015 - val_sparse_categorical_accuracy: 0.6000
# Epoch 147/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6873 - sparse_categorical_accuracy: 0.5412 - val_loss: 0.7016 - val_sparse_categorical_accuracy: 0.6000
# Epoch 148/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6715 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.7015 - val_sparse_categorical_accuracy: 0.6000
# Epoch 149/1000
# 6/6 [==============================] - 32s 5s/step - loss: 0.6704 - sparse_categorical_accuracy: 0.6471 - val_loss: 0.7015 - val_sparse_categorical_accuracy: 0.6000
# Epoch 150/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6744 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7015 - val_sparse_categorical_accuracy: 0.6000
# Epoch 151/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6718 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7014 - val_sparse_categorical_accuracy: 0.6000
# Epoch 152/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6810 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7013 - val_sparse_categorical_accuracy: 0.6000
# Epoch 153/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6742 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7013 - val_sparse_categorical_accuracy: 0.6000
# Epoch 154/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6858 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7012 - val_sparse_categorical_accuracy: 0.6000
# Epoch 155/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6741 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7011 - val_sparse_categorical_accuracy: 0.6000
# Epoch 156/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6777 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7011 - val_sparse_categorical_accuracy: 0.6000
# Epoch 157/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6730 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7010 - val_sparse_categorical_accuracy: 0.6000
# Epoch 158/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6740 - sparse_categorical_accuracy: 0.6471 - val_loss: 0.7010 - val_sparse_categorical_accuracy: 0.6000
# Epoch 159/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6764 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7009 - val_sparse_categorical_accuracy: 0.6000
# Epoch 160/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6699 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7008 - val_sparse_categorical_accuracy: 0.6000
# Epoch 161/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6648 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7008 - val_sparse_categorical_accuracy: 0.6000
# Epoch 162/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6800 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7008 - val_sparse_categorical_accuracy: 0.6000
# Epoch 163/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6821 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7008 - val_sparse_categorical_accuracy: 0.6000
# Epoch 164/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6825 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.7008 - val_sparse_categorical_accuracy: 0.6000
# Epoch 165/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6713 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7008 - val_sparse_categorical_accuracy: 0.6000
# Epoch 166/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6663 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7007 - val_sparse_categorical_accuracy: 0.6000
# Epoch 167/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6689 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7007 - val_sparse_categorical_accuracy: 0.6000
# Epoch 168/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6604 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7006 - val_sparse_categorical_accuracy: 0.6000
# Epoch 169/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6579 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.7005 - val_sparse_categorical_accuracy: 0.6000
# Epoch 170/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6751 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.7004 - val_sparse_categorical_accuracy: 0.6000
# Epoch 171/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6570 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7004 - val_sparse_categorical_accuracy: 0.6000
# Epoch 172/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6750 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7003 - val_sparse_categorical_accuracy: 0.6000
# Epoch 173/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6795 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7003 - val_sparse_categorical_accuracy: 0.6000
# Epoch 174/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6733 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7002 - val_sparse_categorical_accuracy: 0.6000
# Epoch 175/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6670 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7002 - val_sparse_categorical_accuracy: 0.6000
# Epoch 176/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6904 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7002 - val_sparse_categorical_accuracy: 0.6000
# Epoch 177/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6730 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7002 - val_sparse_categorical_accuracy: 0.6000
# Epoch 178/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6607 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7002 - val_sparse_categorical_accuracy: 0.6000
# Epoch 179/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6587 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7002 - val_sparse_categorical_accuracy: 0.6000
# Epoch 180/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6746 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7002 - val_sparse_categorical_accuracy: 0.6000
# Epoch 181/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6642 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7002 - val_sparse_categorical_accuracy: 0.6000
# Epoch 182/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6688 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7002 - val_sparse_categorical_accuracy: 0.6000
# Epoch 183/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6732 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.7002 - val_sparse_categorical_accuracy: 0.6000
# Epoch 184/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6632 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.7001 - val_sparse_categorical_accuracy: 0.6000
# Epoch 185/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6787 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.7001 - val_sparse_categorical_accuracy: 0.6000
# Epoch 186/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6840 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7000 - val_sparse_categorical_accuracy: 0.6000
# Epoch 187/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6685 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7000 - val_sparse_categorical_accuracy: 0.6000
# Epoch 188/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6699 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.7000 - val_sparse_categorical_accuracy: 0.6000
# Epoch 189/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6717 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.7000 - val_sparse_categorical_accuracy: 0.6000
# Epoch 190/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6790 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6999 - val_sparse_categorical_accuracy: 0.6000
# Epoch 191/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6752 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6999 - val_sparse_categorical_accuracy: 0.6000
# Epoch 192/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6639 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.6999 - val_sparse_categorical_accuracy: 0.6000
# Epoch 193/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6675 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.6999 - val_sparse_categorical_accuracy: 0.6000
# Epoch 194/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6700 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6999 - val_sparse_categorical_accuracy: 0.6000
# Epoch 195/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6771 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6999 - val_sparse_categorical_accuracy: 0.6000
# Epoch 196/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6678 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6998 - val_sparse_categorical_accuracy: 0.6000
# Epoch 197/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6615 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6998 - val_sparse_categorical_accuracy: 0.6000
# Epoch 198/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6728 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6998 - val_sparse_categorical_accuracy: 0.6000
# Epoch 199/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6700 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6998 - val_sparse_categorical_accuracy: 0.6000
# Epoch 200/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6748 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6997 - val_sparse_categorical_accuracy: 0.6000
# Epoch 201/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6727 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6997 - val_sparse_categorical_accuracy: 0.6000
# Epoch 202/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6609 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.6997 - val_sparse_categorical_accuracy: 0.6000
# Epoch 203/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6694 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.6997 - val_sparse_categorical_accuracy: 0.6000
# Epoch 204/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6688 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6997 - val_sparse_categorical_accuracy: 0.6000
# Epoch 205/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6677 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6997 - val_sparse_categorical_accuracy: 0.6000
# Epoch 206/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6775 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6997 - val_sparse_categorical_accuracy: 0.6000
# Epoch 207/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6555 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.6000
# Epoch 208/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6781 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.6000
# Epoch 209/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6637 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.6000
# Epoch 210/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6641 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.6000
# Epoch 211/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6896 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.6000
# Epoch 212/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6642 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.6000
# Epoch 213/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6741 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.6000
# Epoch 214/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6726 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.6000
# Epoch 215/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6809 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.6000
# Epoch 216/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6609 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.6000
# Epoch 217/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6855 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.6000
# Epoch 218/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6749 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.6000
# Epoch 219/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6669 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 220/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6792 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 221/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6760 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 222/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6632 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 223/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6658 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 224/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6814 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 225/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6682 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 226/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6824 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 227/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6594 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 228/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6668 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 229/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6719 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6994 - val_sparse_categorical_accuracy: 0.6000
# Epoch 230/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6678 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 231/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6754 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 232/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6686 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 233/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6676 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 234/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6679 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6994 - val_sparse_categorical_accuracy: 0.6000
# Epoch 235/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6527 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 236/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6754 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6994 - val_sparse_categorical_accuracy: 0.6000
# Epoch 237/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6805 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 238/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6803 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 239/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6734 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 240/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6616 - sparse_categorical_accuracy: 0.6471 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 241/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6755 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6995 - val_sparse_categorical_accuracy: 0.6000
# Epoch 242/1000
# ...
# Epoch 143/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6690 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6487 - val_sparse_categorical_accuracy: 0.6000
# Epoch 144/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6587 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6487 - val_sparse_categorical_accuracy: 0.6000
# Epoch 145/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6741 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6487 - val_sparse_categorical_accuracy: 0.6000
# Epoch 146/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6673 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6488 - val_sparse_categorical_accuracy: 0.6000
# Epoch 147/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6740 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6488 - val_sparse_categorical_accuracy: 0.6000
# Epoch 148/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6624 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6487 - val_sparse_categorical_accuracy: 0.6000
# Epoch 149/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6601 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6487 - val_sparse_categorical_accuracy: 0.6000
# Epoch 150/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6585 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6487 - val_sparse_categorical_accuracy: 0.6000
# Epoch 151/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6493 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6488 - val_sparse_categorical_accuracy: 0.6000
# Epoch 152/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6631 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6488 - val_sparse_categorical_accuracy: 0.6000
# Epoch 153/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6633 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6488 - val_sparse_categorical_accuracy: 0.6000
# Epoch 154/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6548 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6488 - val_sparse_categorical_accuracy: 0.6000
# 5e-06 [154, [0.662934422492981, 0.6117647290229797], [0.6486823558807373, 0.6000000238418579], [0.670291006565094, 0.6000000238418579]]
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Learning rate: 5e-06    Trainable: False
# Model: "tf_bert_for_sequence_classification_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bert (TFBertMainLayer)      multiple                  108310272
#
#  dropout_379 (Dropout)       multiple                  0
#
#  classifier (Dense)          multiple                  1538
#
# =================================================================
# Total params: 108,311,810
# Trainable params: 1,538
# Non-trainable params: 108,310,272
# _________________________________________________________________
# Epoch 1/1000
# 6/6 [==============================] - 45s 6s/step - loss: 0.6792 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6965 - val_sparse_categorical_accuracy: 0.5333
# Epoch 2/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6814 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6960 - val_sparse_categorical_accuracy: 0.5333
# Epoch 3/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6836 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.6953 - val_sparse_categorical_accuracy: 0.5333
# Epoch 4/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6810 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.6948 - val_sparse_categorical_accuracy: 0.5333
# Epoch 5/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6854 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6942 - val_sparse_categorical_accuracy: 0.6000
# Epoch 6/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6816 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6937 - val_sparse_categorical_accuracy: 0.5333
# Epoch 7/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6748 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6933 - val_sparse_categorical_accuracy: 0.5333
# Epoch 8/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6803 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6928 - val_sparse_categorical_accuracy: 0.5333
# Epoch 9/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6861 - sparse_categorical_accuracy: 0.5294 - val_loss: 0.6926 - val_sparse_categorical_accuracy: 0.5333
# Epoch 10/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6813 - sparse_categorical_accuracy: 0.5294 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5333
# Epoch 11/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6833 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.6917 - val_sparse_categorical_accuracy: 0.5333
# Epoch 12/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6775 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6914 - val_sparse_categorical_accuracy: 0.5333
# Epoch 13/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6820 - sparse_categorical_accuracy: 0.5529 - val_loss: 0.6911 - val_sparse_categorical_accuracy: 0.6000
# Epoch 14/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6807 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.6907 - val_sparse_categorical_accuracy: 0.6000
# Epoch 15/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6890 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6903 - val_sparse_categorical_accuracy: 0.6000
# Epoch 16/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6877 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6899 - val_sparse_categorical_accuracy: 0.6000
# Epoch 17/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6845 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6897 - val_sparse_categorical_accuracy: 0.6000
# Epoch 18/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6882 - sparse_categorical_accuracy: 0.5647 - val_loss: 0.6893 - val_sparse_categorical_accuracy: 0.6000
# Epoch 19/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6898 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6889 - val_sparse_categorical_accuracy: 0.6000
# Epoch 20/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6588 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6887 - val_sparse_categorical_accuracy: 0.6000
# Epoch 21/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6717 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6885 - val_sparse_categorical_accuracy: 0.6000
# Epoch 22/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6614 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6883 - val_sparse_categorical_accuracy: 0.6000
# Epoch 23/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6803 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6881 - val_sparse_categorical_accuracy: 0.6000
# Epoch 24/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6711 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6879 - val_sparse_categorical_accuracy: 0.6000
# Epoch 25/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6778 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.6876 - val_sparse_categorical_accuracy: 0.6000
# Epoch 26/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6787 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6873 - val_sparse_categorical_accuracy: 0.6000
# Epoch 27/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6723 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6872 - val_sparse_categorical_accuracy: 0.6000
# Epoch 28/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6869 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6870 - val_sparse_categorical_accuracy: 0.6000
# Epoch 29/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6788 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6869 - val_sparse_categorical_accuracy: 0.6000
# Epoch 30/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6715 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6867 - val_sparse_categorical_accuracy: 0.6000
# Epoch 31/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6811 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6864 - val_sparse_categorical_accuracy: 0.6000
# Epoch 32/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6720 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6861 - val_sparse_categorical_accuracy: 0.6000
# Epoch 33/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6744 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6860 - val_sparse_categorical_accuracy: 0.6000
# Epoch 34/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6734 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6859 - val_sparse_categorical_accuracy: 0.6000
# Epoch 35/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6788 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6858 - val_sparse_categorical_accuracy: 0.6000
# Epoch 36/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6616 - sparse_categorical_accuracy: 0.5882 - val_loss: 0.6856 - val_sparse_categorical_accuracy: 0.6000
# Epoch 37/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6666 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6855 - val_sparse_categorical_accuracy: 0.6000
# Epoch 38/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6772 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6854 - val_sparse_categorical_accuracy: 0.6000
# Epoch 39/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6671 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6854 - val_sparse_categorical_accuracy: 0.6000
# Epoch 40/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6615 - sparse_categorical_accuracy: 0.6353 - val_loss: 0.6853 - val_sparse_categorical_accuracy: 0.6000
# Epoch 41/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6576 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6853 - val_sparse_categorical_accuracy: 0.6000
# Epoch 42/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6802 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6851 - val_sparse_categorical_accuracy: 0.6000
# Epoch 43/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6664 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6849 - val_sparse_categorical_accuracy: 0.6000
# Epoch 44/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6671 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6848 - val_sparse_categorical_accuracy: 0.6000
# Epoch 45/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6622 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6847 - val_sparse_categorical_accuracy: 0.6000
# Epoch 46/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6692 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6847 - val_sparse_categorical_accuracy: 0.6000
# Epoch 47/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6672 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6848 - val_sparse_categorical_accuracy: 0.6000
# Epoch 48/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6731 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6847 - val_sparse_categorical_accuracy: 0.6000
# Epoch 49/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6809 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6847 - val_sparse_categorical_accuracy: 0.6000
# Epoch 50/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6742 - sparse_categorical_accuracy: 0.5765 - val_loss: 0.6847 - val_sparse_categorical_accuracy: 0.6000
# Epoch 51/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6775 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6847 - val_sparse_categorical_accuracy: 0.6000
# Epoch 52/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6777 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6847 - val_sparse_categorical_accuracy: 0.6000
# Epoch 53/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6668 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6845 - val_sparse_categorical_accuracy: 0.6000
# Epoch 54/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6636 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6845 - val_sparse_categorical_accuracy: 0.6000
# Epoch 55/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6747 - sparse_categorical_accuracy: 0.6000 - val_loss: 0.6844 - val_sparse_categorical_accuracy: 0.6000
# Epoch 56/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6662 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6844 - val_sparse_categorical_accuracy: 0.6000
# Epoch 57/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6765 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6843 - val_sparse_categorical_accuracy: 0.6000
# Epoch 58/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6747 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6843 - val_sparse_categorical_accuracy: 0.6000
# Epoch 59/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6644 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6843 - val_sparse_categorical_accuracy: 0.6000
# Epoch 60/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6687 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6843 - val_sparse_categorical_accuracy: 0.6000
# Epoch 61/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6672 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6843 - val_sparse_categorical_accuracy: 0.6000
# Epoch 62/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6672 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6843 - val_sparse_categorical_accuracy: 0.6000
# Epoch 63/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6716 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6844 - val_sparse_categorical_accuracy: 0.6000
# Epoch 64/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6549 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6844 - val_sparse_categorical_accuracy: 0.6000
# Epoch 65/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6669 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6845 - val_sparse_categorical_accuracy: 0.6000
# Epoch 66/1000
# 6/6 [==============================] - 30s 5s/step - loss: 0.6777 - sparse_categorical_accuracy: 0.6118 - val_loss: 0.6844 - val_sparse_categorical_accuracy: 0.6000
# Epoch 67/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6691 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6844 - val_sparse_categorical_accuracy: 0.6000
# Epoch 68/1000
# 6/6 [==============================] - 31s 5s/step - loss: 0.6598 - sparse_categorical_accuracy: 0.6235 - val_loss: 0.6844 - val_sparse_categorical_accuracy: 0.6000
# 5e-06 [68, [0.6661638617515564, 0.6117647290229797], [0.6842529773712158, 0.6000000238418579], [0.678932249546051, 0.6000000238418579]]
